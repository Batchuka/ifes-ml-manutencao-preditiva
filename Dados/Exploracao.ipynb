# %% [markdown]
# # O conjunto de dados

# %% [markdown]
# Agora temos os conjuntos específicos de dados:
# - KA04_Teste:
#     1. corrente_fase_1
#     2. corrente_fase_2
#     3. time_KA04_Teste
#     4. vibration_KA04_Teste

# %%
# Carrega o arquivo .mat
# KA04 = sio.loadmat('sinais_falha/KA04/KA04_Teste/vibration_KA04_Teste.mat')
KA04 = sio.loadmat('sinais_falha/KA04/KA04_Treino/corrente_fase1_KA04_Treino.mat')

# Explorar estrutura
print(KA04.keys())
print(KA04['vibration_KA04_Treino'].shape)
print(KA04['corrente_fase1_KA04_Treino'].shape)
# for key, value in KA04_Teste.items():
#     print(f'\ninfo: {key}')
#     if hasattr(value, 'shape'):
#         print(f'valor: {value.shape}\n')
#     print(f'valor: {value}\n')


# # Converte o dicionário em DataFrame
# df_mat_classes_contents = pd.DataFrame(mat_classes_contents['classes'])

# # Visualiza o DataFrame
# df_mat_classes_contents
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'N15_M01_F10_KA04_8', 'corrente_fase1_KA04_Treino', 'vibration_KA04_Treino'])
# (1, 256001)
# (1, 256001)

# %% [markdown]
# # Classes e Vibrations

# %% [markdown]
# Nós temos um conjunto de dados que estão contidos nos arquivos 'mat_classes.mat' e 'mat_vibration.mat'. Para que possamos explorar seu conteúdo, é preciso fazer a leitura da extensão .mat.

# %%
# Carrega o arquivo .mat
mat_classes_contents = sio.loadmat('mat_classes.mat')

# Explorar estrutura
print(mat_classes_contents.keys())

# Converte o dicionário em DataFrame
df_mat_classes_contents = pd.DataFrame(mat_classes_contents['classes'])

# Visualiza o DataFrame
df_mat_classes_contents
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'classes'])
#          0         1         2         3         4         5         6     \
# 0   -0.048828  0.216675  0.234985  0.390625  0.003052 -0.265503 -0.143433
# 1   -0.137329  0.036621  0.231934  0.466919  0.161743 -0.112915 -0.277710
# 2    0.146484  0.030518 -0.103760  0.119019 -0.250244 -0.201416 -0.170898
# 3   -0.094604 -0.048828 -0.085449 -0.192261 -0.094604 -0.067139 -0.045776
# 4    0.265503  0.399780  0.073242  0.299072 -0.198364 -0.119019 -0.064087
# ..        ...       ...       ...       ...       ...       ...       ...
# 995 -0.054932  0.027466  0.097656  0.186157  0.204468  0.170898  0.033569
# 996 -0.180054 -0.265503 -0.219727 -0.079346  0.143433  0.280762  0.262451
# 997  0.372314  0.149536 -0.149536 -0.418091 -0.469971 -0.308228 -0.061035
# 998 -0.088501 -0.115967 -0.180054 -0.122070  0.012207  0.207520  0.390625
# 999 -0.039673  0.009155  0.024414  0.073242  0.067139  0.164795  0.357056
#
# ...

# %%
# Carrega o arquivo .mat
mat_vibration_contents = sio.loadmat('mat_vibration.mat')

# Explorar estrutura
print(mat_vibration_contents.keys())

# Converte o dicionário em DataFrame
df_mat_vibration_contents = pd.DataFrame(mat_vibration_contents['A'])

# print(mat_vibration_contents['N15_M07_F10_K001_1'])

# # Visualiza o DataFrame
# df_mat_vibration_contents
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'A', 'B', 'C', 'D', 'E', 'N15_M07_F10_K001_1', 'N15_M07_F10_KA04_1', 'N15_M07_F10_KA15_1', 'N15_M07_F10_KB23_1', 'N15_M07_F10_KB27_1', 'N15_M07_F10_KI04_1', 'ans', 'class01', 'class02', 'class03', 'class04', 'class05', 'class06', 'class1', 'class2', 'class3', 'class4', 'class5', 'class6', 'mat_vibration', 'matrix', 'n_var', 'phase_current_1_K001_1', 'phase_current_1_KA04_1', 'phase_current_1_KA15_1', 'phase_current_1_KB23_1', 'phase_current_1_KB27_1', 'phase_current_2_K001_1', 'phase_current_2_KA04_1', 'phase_current_2_KA15_1', 'phase_current_2_KB23_1', 'phase_current_2_KB27_1', 'signal', 'tempo_K001_1', 'tempo_KA04_1', 'tempo_KA15_1', 'tempo_KB23_1', 'tempo_KB27_1', 'vet', 'vibration_1_K001_1', 'vibration_1_KA04_1', 'vibration_1_KA15_1', 'vibration_1_KB23_1', 'vibration_1_KB27_1', 'vibration_1_KI04_1'])

# %%
# Carrega o arquivo .mat
mat_vibration_contents = sio.loadmat('sinais_falha\KA04\KA04_Teste\corrente_fase1_KA04_Teste.mat')

# Explorar estrutura
print(mat_vibration_contents.keys())

# # Converte o dicionário em DataFrame
# df_mat_vibration_contents = pd.DataFrame(mat_vibration_contents['A'])

# print(mat_vibration_contents['N15_M07_F10_K001_1'])

# # Visualiza o DataFrame
# df_mat_vibration_contents
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'N09_M07_F10_KA04_15', 'N15_M01_F10_KA04_8', 'corrente_fase1_KA04_Teste', 'corrente_fase1_KA04_Treino', 'corrente_fase2_KA04_Treino', 'time_KA04_Treino', 'vibration_KA04_Teste', 'vibration_KA04_Treino'])

# %% [markdown]
# # Imports

# %%
import scipy.io as sio
import pandas as pd
